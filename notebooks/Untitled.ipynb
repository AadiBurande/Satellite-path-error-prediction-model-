# %%
import pandas as pd

# Load the dataset
# The '../' goes up one level from 'notebooks/' to the main project folder
file_path = 'D:\TY\SIH_Data_PS-08\DATA_GEO_Train.csv'
df = pd.read_csv(file_path, parse_dates=['timestamp_column_name']) # Make sure to use the actual timestamp column name

# Display the first 5 rows to verify it loaded correctly
print(df.head())

# Get a quick summary of the data
print(df.info())
